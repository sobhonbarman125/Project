# %% [markdown]
# <a href="https://colab.research.google.com/github/sobhonbarman125/Project/blob/main/Facebook_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %%
pip install numpy

# %%
pip install pandas

# %%
pip install matplotlib

# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
import io
import unicodedata
import numpy as np
import re
import string
from numpy import linalg
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import PunktSentenceTokenizer
from nltk.tokenize import PunktSentenceTokenizer
from nltk.corpus import webtext
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

# %%
with open('kindle.txt', encoding ='ISO-8859-2') as f:
    text = f.read()
sent_tokenizer = PunktSentenceTokenizer(text)
sents = sent_tokenizer.tokenize(text)

# %%
nltk.download('punkt')
print(word_tokenize(text))
print(sent_tokenize(text))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %%
porter_stemmer = PorterStemmer()

nltk_tokens = nltk.word_tokenize(text)

# %%
for w in nltk_tokens:
    print ("Actual: % s Stem: % s" % (w, porter_stemmer.stem(w)))
# Out:
# Streaming output truncated to the last 5000 lines.
# Actual: top Stem: top
# Actual: five Stem: five
# Actual: favorite Stem: favorit
# Actual: features Stem: featur
# Actual: . Stem: .
# Actual: I Stem: i
# Actual: recently Stem: recent
# Actual: read Stem: read
# Actual: a Stem: a
# Actual: real Stem: real
# Actual: book Stem: book
# Actual: -- Stem: --
# Actual: after Stem: after
# Actual: keeping Stem: keep
# Actual: constant Stem: constant
# Actual: company Stem: compani
# Actual: with Stem: with
# Actual: my Stem: my
# Actual: Kindle Stem: kindl
# Actual: since Stem: sinc
# Actual: Christmas Stem: christma
# Actual: . Stem: .
# Actual: The Stem: the
# Actual: thing Stem: thing
# Actual: I Stem: i
# Actual: missed Stem: miss
# Actual: most Stem: most
# Actual: about Stem: about
# Actual: going Stem: go
# Actual: back Stem: back
# Actual: to Stem: to
# Actual: a Stem: a
# Actual: real Stem: real
# Actual: book Stem: book
# Actual: was Stem: wa
# Actual: the Stem: the
# ...

# %%
wordnet_lemmatizer = WordNetLemmatizer()
nltk_tokens = nltk.word_tokenize(text)

# %%
nltk.download('wordnet')
for w in nltk_tokens:
    print ("Actual: % s Lemma: % s" % (w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Streaming output truncated to the last 5000 lines.
# Actual: top Lemma: top
# Actual: five Lemma: five
# Actual: favorite Lemma: favorite
# Actual: features Lemma: feature
# Actual: . Lemma: .
# Actual: I Lemma: I
# Actual: recently Lemma: recently
# Actual: read Lemma: read
# Actual: a Lemma: a
# Actual: real Lemma: real
# Actual: book Lemma: book
# Actual: -- Lemma: --
# Actual: after Lemma: after
# Actual: keeping Lemma: keeping
# Actual: constant Lemma: constant
# Actual: company Lemma: company
# Actual: with Lemma: with
# Actual: my Lemma: my
# Actual: Kindle Lemma: Kindle
# Actual: since Lemma: since
# Actual: Christmas Lemma: Christmas
# Actual: . Lemma: .
# Actual: The Lemma: The
# Actual: thing Lemma: thing
# Actual: I Lemma: I
# Actual: missed Lemma: missed
# Actual: most Lemma: most
# Actual: about Lemma: about
# Actual: going Lemma: going
# Actual: back Lemma: back
# Actual: to Lemma: to
# Actual: a Lemma: a
# ...

# %%
 nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
text = nltk.word_tokenize(text)
print(nltk.pos_tag(text))
# Out:
# [('FBPost', 'NNP'), ('Label', 'NNP'), ('0', 'CD'), ('Drug', 'NNP'), ('Runners', 'NNPS'), ('and', 'CC'), ('a', 'DT'), ('U.S', 'NNP'), ('.', '.'), ('Senator', 'NNP'), ('have', 'VBP'), ('something', 'NN'), ('to', 'TO'), ('do', 'VB'), ('with', 'IN'), ('the', 'DT'), ('Murder', 'NNP'), ('http', 'NN'), (':', ':'), ('//www.amazon.com/Circumstantial-Evidence-Getting-Florida-Bozarth-ebook/dp/B004FPZ452/ref=pd_rhf_p_t_1', 'JJ'), ('The', 'DT'), ('State', 'NNP'), ('Attorney', 'NNP'), ('Knows', 'NNP'), ('...', ':'), ('NOW', 'NNP'), ('So', 'NNP'), ('Will', 'NNP'), ('You', 'PRP'), ('.', '.'), ('GET', 'VB'), ('Ypur', 'NNP'), ('Copy', 'NNP'), ('TODAY', 'NNP'), ('O', 'NNP'), ('1', 'CD'), ("''", "''"), ('Heres', 'VBZ'), ('a', 'DT'), ('single', 'JJ'), (',', ','), ('to', 'TO'), ('add', 'VB'), (',', ','), ('to', 'TO'), ('Kindle', 'NNP'), ('.', '.'), ('Just', 'NNP'), ('read', 'VBD'), ('this', 'DT'), ('19th', 'JJ'), ('century', 'NN'), ('story', 'NN'), (':', ':'), ('``', '``'), ("''", "''"), ('The', 'DT'), ('
# ...

# %%
# !pip install nltk
nltk.download('punkt')
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
sid = SentimentIntensityAnalyzer()
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
with open('kindle.txt', encoding ='ISO-8859-2') as f:
    for text in f.read().split('\n'):
        print(text)
        scores = sid.polarity_scores(text)
        for key in sorted(scores):
            print('{0}: {1}, '.format(key, scores[key]), end ='')

    print()
# Out:
# 	FBPost	Label
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, 0	Drug Runners and  a U.S. Senator have something to do with the Murder http://www.amazon.com/Circumstantial-Evidence-Getting-Florida-Bozarth-ebook/dp/B004FPZ452/ref=pd_rhf_p_t_1 The State Attorney Knows... NOW So Will You. GET Ypur Copy TODAY	O
# compound: -0.6908, neg: 0.164, neu: 0.836, pos: 0.0, 1	"Heres a single, to add, to Kindle. Just read this 19th century story: ""The Ghost of Round Island"". Its about a man (French/American Indian) and his dog sled transporting a woman across the ice, from Mackinac Island to Cheboygan - and the ghost that..."	O
# compound: -0.5574, neg: 0.108, neu: 0.892, pos: 0.0, 2	If you tire of Non-Fiction.. Check out http://www.amazon.com/s/ref=nb_sb_noss?url=search-alias%3Daps&field-keywords=danielle+lee+zwissler+&x=0&y=0	O
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, 3	Ghost of Round Island is supposedly nonfiction.	O
# ...
